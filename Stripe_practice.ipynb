# %% [markdown]
# <a href="https://colab.research.google.com/github/sindla97/Machine-Learning/blob/main/Stripe_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_breast_cancer
data=load_breast_cancer(as_frame=True)
df=pd.concat([data['data'],data['target']],axis=1)
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
df['mean radius'].describe()
# Out:
# count    569.000000
# mean      14.127292
# std        3.524049
# min        6.981000
# 25%       11.700000
# 50%       13.370000
# 75%       15.780000
# max       28.110000
# Name: mean radius, dtype: float64

# %%
sns.distplot(df['mean radius'])
# Out:
# <ipython-input-114-458af9634547>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['mean radius'])
# <Axes: xlabel='mean radius', ylabel='Density'>

# %%
np.linspace(df['mean radius'].min(), df['mean radius'].max(),5)
# Out:
# array([ 6.981  , 12.26325, 17.5455 , 22.82775, 28.11   ])

# %%
df.groupby('target')['mean radius'].mean()
# Out:
# target
# 0    17.462830
# 1    12.146524
# Name: mean radius, dtype: float64

# %%
df['binned_mean_radius']= df['mean radius'].apply( lambda x: 1 if x <12.2635 else 2 if x >=12.2635 and x<17.5455 else 3 if x>=17.5455 and x<22.82775 else 4)

# %%
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
df.groupby('binned_mean_radius').apply(lambda x: x['target'].sum()/x['target'].count())
# Out:
# <ipython-input-119-c489c8dd932b>:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby('binned_mean_radius').apply(lambda x: x['target'].sum()/x['target'].count())
# binned_mean_radius
# 1    0.968586
# 2    0.619565
# 3    0.011111
# 4    0.000000
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaled_cols = [ x for x in df.columns if x not in ['binned_mean_radius','target']]
scaled_cols
# Out:
# ['mean radius',
#  'mean texture',
#  'mean perimeter',
#  'mean area',
#  'mean smoothness',
#  'mean compactness',
#  'mean concavity',
#  'mean concave points',
#  'mean symmetry',
#  'mean fractal dimension',
#  'radius error',
#  'texture error',
#  'perimeter error',
#  'area error',
#  'smoothness error',
#  'compactness error',
#  'concavity error',
#  'concave points error',
#  'symmetry error',
#  'fractal dimension error',
#  'worst radius',
#  'worst texture',
#  'worst perimeter',
#  'worst area',
#  'worst smoothness',
#  'worst compactness',
#  'worst concavity',
#  'worst concave points',
#  'worst symmetry',
#  'worst fractal dimension']

# %%
df_train, df_test,y_train,y_test=train_test_split(df[scaled_cols],df['target'], test_size=0.25)

# %%
ss=StandardScaler()
df_train[scaled_cols]=ss.fit_transform(df_train[scaled_cols])
df_test[scaled_cols]=ss.transform(df_test[scaled_cols])

# %%
df_train
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 386    -0.539835     -1.164280       -0.540674  -0.549835        -1.117321
# 259     0.411251      3.250657        0.492049   0.274868         0.662920
# 201     0.987059      0.021654        0.964482   0.877436        -0.510260
# 427    -0.943760      0.624824       -0.954674  -0.847475        -0.628143
# 368     2.181645     -0.447731        2.033673   2.610217        -0.216612
# ..           ...           ...             ...        ...              ...
# 119     1.104512      0.178115        0.927185   0.966057        -0.909791
# 32      0.838093      1.078336        0.869167   0.724972         1.608805
# 532    -0.118722     -0.656346       -0.168529  -0.218963        -0.292142
# 360    -0.445299     -0.261791       -0.514151  -0.462672        -1.591675
# 481    -0.055698      0.003513       -0.128331  -0.139087        -1.199909
#
# ...

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(df_train,y_train)
# Out:
# LogisticRegression()

# %%
ss=StandardScaler()
for i in scaled_cols:
  df[i]=ss.fit()

# %%
titanic = pd.read_csv("/content/titanic.csv")
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.dtypes.reset_index()
# Out:
#           index        0
# 0   PassengerId    int64
# 1      Survived    int64
# 2        Pclass    int64
# 3          Name   object
# 4           Sex   object
# 5           Age  float64
# 6         SibSp    int64
# 7         Parch    int64
# 8        Ticket   object
# 9          Fare  float64
# 10        Cabin   object
# 11     Embarked   object

# %%
null=titanic.isnull().sum(axis=0).reset_index()
null['percentage']=null.apply(lambda x: (x[0]/titanic.shape[0])*100, axis=1)
null
# Out:
#           index    0  percentage
# 0   PassengerId    0    0.000000
# 1      Survived    0    0.000000
# 2        Pclass    0    0.000000
# 3          Name    0    0.000000
# 4           Sex    0    0.000000
# 5           Age  177   19.865320
# 6         SibSp    0    0.000000
# 7         Parch    0    0.000000
# 8        Ticket    0    0.000000
# 9          Fare    0    0.000000
# 10        Cabin  687   77.104377
# 11     Embarked    2    0.224467

# %%
col_lst=list(null[null['percentage']<75]['index'])
col_lst.remove('Name')
col_lst
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Embarked']

# %%
sns.countplot(x=titanic['Pclass'],hue=titanic['Survived'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
titanic.groupby('Pclass')['Survived'].value_counts().reset_index().pivot_table(index='Pclass',columns='Survived',values='count').reset_index()
# Out:
# Survived  Pclass      0      1
# 0              1   80.0  136.0
# 1              2   97.0   87.0
# 2              3  372.0  119.0

# %%
titanic.groupby('Pclass').apply(lambda x: x['Survived'].sum()/x['Survived'].count())
# Out:
# <ipython-input-43-22753e6fa1c5>:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   titanic.groupby('Pclass').apply(lambda x: x['Survived'].sum()/x['Survived'].count())
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# dtype: float64

# %%
# plt.density(titanic['Age'])
import seaborn as sns

sns.set_style('whitegrid')
sns.displot(titanic['Age'])

# plt.hist(titanic['Age'], bins=6000)
# plt.show()

# %%
titanic['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
from sklearn.preprocessing import KBinsDiscretizer


# Create a KBinsDiscretizer object
discretizer = KBinsDiscretizer(n_bins=5, encode='ordinal', strategy='uniform')

# Fit and transform the data
titanic['age_binned'] =discretizer.fit_transform(titanic[['Age']].fillna(0))
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic['Fare']

# %%
discretizer.bin_edges_[0]
# Out:
# array([ 0., 16., 32., 48., 64., 80.])

# %%
titanic.groupby('age_binned').apply(lambda x: (x['Survived'].sum()/x['Survived'].count())*100)
# Out:
# <ipython-input-53-a8fef2636ec9>:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   titanic.groupby('age_binned').apply(lambda x: (x['Survived'].sum()/x['Survived'].count())*100)
# age_binned
# 0.0    38.846154
# 1.0    36.231884
# 2.0    40.101523
# 3.0    47.368421
# 4.0     7.692308
# dtype: float64

# %%
np.linspace(titanic['Age'].min(),titanic['Age'].max(),5)
# Out:
# array([ 0.42 , 20.315, 40.21 , 60.105, 80.   ])

# %%
titanic[['Age','Survived']].corr()
# Out:
#                Age  Survived
# Age       1.000000 -0.077221
# Survived -0.077221  1.000000

# %%
cat_cols=[x for x in titanic.columns if titanic[x].dtypes=='object' and x not in ['Name','Ticket','Cabin']]
print(cat_cols)
cols=[x for x in col_lst if x not in ['PassengerId','Ticket','Cabin','Survived']]
print(cols)
# Out:
# ['Sex', 'Embarked']
# ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for i in cat_cols:
   le=LabelEncoder()
   titanic[i]=le.fit_transform(titanic[i])

# %%
for k in ['Pclass', 'Sex', 'SibSp', 'Parch','Embarked']:
    titanic[k]=titanic[k].astype('category')

# %%
titanic['Cabin'].value_counts()
# Out:
# Cabin
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(titanic,titanic['Survived'],test_size=0.2,random_state=123)

# %%
X_train.fillna({'Age':X_train['Age'].mean()}, inplace=True)

# %%
X_test.fillna({'Age':X_train['Age'].mean()}, inplace=True)

# %%
X_train,X_val,y_train,y_val=train_test_split(X_train,y_train,test_size=0.3,random_state=1234)

# %%
from sklearn.linear_model import LogisticRegression
LR=LogisticRegression()

# %%
X_train[cols].isnull().sum(axis=0)
# Out:
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
LR.fit(X_train[cols],y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_train_preds=LR.predict(X_train[cols])
y_test_preds=LR.predict(X_test[cols])

# %%
from sklearn.metrics import *

# %%
confusion_matrix(y_test,y_test_preds),confusion_matrix(y_train,y_train_preds)
# Out:
# (array([[96, 18],
#         [15, 50]]),
#  array([[249,  53],
#         [ 58, 138]]))

# %%
accuracy_score(y_test,y_test_preds),accuracy_score(y_train,y_train_preds)
# Out:
# (0.8156424581005587, 0.7771084337349398)

# %%
roc_auc_score(y_test,LR.predict_proba(X_test[cols])[:,1]),roc_auc_score(y_train,LR.predict_proba(X_train[cols])[:,1])
# Out:
# (0.8747638326585696, 0.8475131774564131)

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import RandomizedSearchCV

# %%
xgbc=XGBClassifier(objective='binary:logistic', column_sample_rate=, columns_sample_bylevel, learning_rate=,max_depth=,early_stopping_rounds=, eval_metric=, reg_lambda, reg_alpha)

xgbc.fit(X,y, eval_set=[(X_val, y_val)])
